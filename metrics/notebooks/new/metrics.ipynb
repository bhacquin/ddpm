# %%
import sys
sys.path.append("/home/tmartorella/ddpm")

from torchmetrics.image.fid import FrechetInceptionDistance
from torchmetrics.image.lpip import LearnedPerceptualImagePatchSimilarity
# from basicsr.metrics.metric_util import reorder_image, to_y_channel
from ddpm.datasets.celebahq import CelebAHQ
from torchvision import transforms
from PIL import Image
import numpy as np
import cv2

t = transforms.Compose([transforms.ToTensor(), transforms.Resize([256]), transforms.CenterCrop([256, 256])])
dataset = CelebAHQ(root="/home/bastien/scitas/bastien/CelebAMask-HQ/CelebA-HQ-img/", transform=t)


def to_pil(img):
    return Image.fromarray((img * 255).permute(1, 2, 0).numpy().astype(np.uint8))


# def _ssim(img1, img2):
#     """Calculate SSIM (structural similarity) for one channel images.

#     It is called by func:`calculate_ssim`.

#     Args:
#         img1 (ndarray): Images with range [0, 255] with order 'HWC'.
#         img2 (ndarray): Images with range [0, 255] with order 'HWC'.

#     Returns:
#         float: ssim result.
#     """

#     C1 = (0.01 * 255)**2
#     C2 = (0.03 * 255)**2

#     img1 = img1.astype(np.float64)
#     img2 = img2.astype(np.float64)
#     kernel = cv2.getGaussianKernel(11, 1.5)
#     window = np.outer(kernel, kernel.transpose())

#     mu1 = cv2.filter2D(img1, -1, window)[5:-5, 5:-5]
#     mu2 = cv2.filter2D(img2, -1, window)[5:-5, 5:-5]
#     mu1_sq = mu1**2
#     mu2_sq = mu2**2
#     mu1_mu2 = mu1 * mu2
#     sigma1_sq = cv2.filter2D(img1**2, -1, window)[5:-5, 5:-5] - mu1_sq
#     sigma2_sq = cv2.filter2D(img2**2, -1, window)[5:-5, 5:-5] - mu2_sq
#     sigma12 = cv2.filter2D(img1 * img2, -1, window)[5:-5, 5:-5] - mu1_mu2

#     ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))
#     return ssim_map.mean()


# def calculate_ssim(img1, img2, crop_border, input_order='HWC', test_y_channel=False):
#     """Calculate SSIM (structural similarity).

#     Ref:
#     Image quality assessment: From error visibility to structural similarity

#     The results are the same as that of the official released MATLAB code in
#     https://ece.uwaterloo.ca/~z70wang/research/ssim/.

#     For three-channel images, SSIM is calculated for each channel and then
#     averaged.

#     Args:
#         img1 (ndarray): Images with range [0, 255].
#         img2 (ndarray): Images with range [0, 255].
#         crop_border (int): Cropped pixels in each edge of an image. These
#             pixels are not involved in the SSIM calculation.
#         input_order (str): Whether the input order is 'HWC' or 'CHW'.
#             Default: 'HWC'.
#         test_y_channel (bool): Test on Y channel of YCbCr. Default: False.

#     Returns:
#         float: ssim result.
#     """

#     assert img1.shape == img2.shape, (f'Image shapes are differnet: {img1.shape}, {img2.shape}.')
#     if input_order not in ['HWC', 'CHW']:
#         raise ValueError(f'Wrong input_order {input_order}. Supported input_orders are ' '"HWC" and "CHW"')
#     img1 = reorder_image(img1, input_order=input_order)
#     img2 = reorder_image(img2, input_order=input_order)
#     img1 = img1.astype(np.float64)
#     img2 = img2.astype(np.float64)

#     if crop_border != 0:
#         img1 = img1[crop_border:-crop_border, crop_border:-crop_border, ...]
#         img2 = img2[crop_border:-crop_border, crop_border:-crop_border, ...]

#     if test_y_channel:
#         img1 = to_y_channel(img1)
#         img2 = to_y_channel(img2)

#     ssims = []
#     for i in range(img1.shape[2]):
#         ssims.append(_ssim(img1[..., i], img2[..., i]))
#     return np.array(ssims).mean()


# def get_metrics(img1, img2):
#     ssim = calculate_ssim(img1, img2, 0)
#     psnr = calculate_psnr(img1, img2, 0)
#     return ssim, psnr

# %%
list(Path("/home/tmartorella/imgs_for_metrics/fid/").glob("*"))

# %%
# !unzip /home/tmartorella/imgs_for_metrics/fid.zip -d /home/tmartorella/imgs_for_metrics/fid/
# Out:
# Archive:  /home/tmartorella/imgs_for_metrics/fid.zip
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/12611/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9089/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/17622/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/15549/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/reconstruction/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/reconstruction/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/ode/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/2191/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/reconstruction/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/reconstruction/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/ode/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19489/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/13707/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/23326/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/25048/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/reconstruction/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/reconstruction/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/ode/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/29726/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/3247/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/reconstruction/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/reconstruction/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/ode/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9775/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/849/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/9044/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/5253/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/water_drop/19712/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/12611/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/9089/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/17622/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/non_clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/non_clipped/200_0.000447214_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/clipped/200_0.0001_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/ode/clipped/200_0.000447214_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/15549/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/reconstruction/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/reconstruction/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/ode/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/2191/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/reconstruction/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/reconstruction/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/ode/non_clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/19489/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-22_12-40/gaussian_blur/13707/ode/non_clipped/
# ...
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2375/ode/clipped/200_0.000928318_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2375/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2375/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2375/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2375/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2375/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2375/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/non_clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/non_clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/non_clipped/200_0.000928318_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/ode/clipped/200_0.000928318_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/2868/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/non_clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/non_clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/non_clipped/200_0.000928318_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/ode/clipped/200_0.000928318_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/4852/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/non_clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/non_clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/non_clipped/200_0.000928318_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/ode/clipped/200_0.000928318_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/29146/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/non_clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/non_clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/non_clipped/200_0.000928318_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/ode/clipped/200_0.000928318_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/25401/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/non_clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/non_clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/non_clipped/200_0.000928318_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/ode/clipped/200_0.000928318_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/original.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/corrupted.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/sde/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/sde/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/sde/non_clipped/399_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/26708/sde/clipped/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/reconstruction/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/reconstruction/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/reconstruction/non_clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/reconstruction/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/reconstruction/clipped/reconstruction_ddim.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/non_clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/non_clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/non_clipped/200_0.0002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/non_clipped/200_0.002_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/non_clipped/200_0.000928318_0.png
#    creating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/clipped/
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/clipped/200_0.000430887_0.png
#   inflating: /home/tmartorella/imgs_for_metrics/fid/fid/2024-05-21_23-30/plasma_noise/8770/ode/clipped/200_0.0002_0.png

# %%
from pathlib import Path
from tqdm.auto import tqdm

files = [f for f in tqdm(list(Path("/home/tmartorella/imgs_for_metrics/fid/").glob("**/*.png"))) if f.is_file()]
files[:20]
# Out:
# 0it [00:00, ?it/s]
# []

# %%
import pandas as pd
info = []
for f in files:
    f_split = str(f).split("/")
    if f.name in ["corrupted.png", "original.png"]:
        info.append({
            "path": f,
            "corruption": f_split[-3],
            "img_id": f_split[-2],
            "filename": f_split[-1],
            "algo": "none",
            "clipping": "none",
            "timestamp": f_split[-4],
        })
    else:
        info.append({
            "path": f,
            "corruption": f_split[-5],
            "img_id": f_split[-4],
            "filename": f_split[-1],
            "algo": f_split[-3],
            "clipping": f_split[-2],
            "timestamp": f_split[-6],
        })

df = pd.DataFrame(info)

# %%
df
# Out:
#                                                     path    corruption img_id  \
# 0      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 1      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 2      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 3      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 4      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# ...                                                  ...           ...    ...
# 14579  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14580  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14581  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14582  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14583  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
#
#                       filename            algo     clipping         timestamp
# 0                corrupted.png            none         none  2024-05-22_12-40
# 1                 original.png            none         none  2024-05-22_12-40
# 2                    399_0.png             sde  non_clipped  2024-05-22_12-40
# 3             200_0.0001_0.png             ode      clipped  2024-05-22_12-40
# 4              200_0.002_0.png             ode      clipped  2024-05-22_12-40
# ...                        ...             ...          ...               ...
# 14579         200_0.0002_0.png             ode  non_clipped  2024-05-21_23-02
# 14580          200_0.001_0.png             ode  non_clipped  2024-05-21_23-02
# 14581    200_0.000447214_0.png             ode  non_clipped  2024-05-21_23-02
# 14582  reconstruction_ddim.png  reconstruction      clipped  2024-05-21_23-02
# 14583  reconstruction_ddim.png  reconstruction  non_clipped  2024-05-21_23-02
#
# [14584 rows x 7 columns]

# %%
df.groupby("corruption")['img_id'].unique().apply(len)
# Out:
# corruption
# brownish_noise                 16
# caustic_noise                  16
# caustic_refraction             16
# checkerboard_cutout           206
# cocentric_sine_waves           16
# fish_eye                       16
# gaussian_blur                  16
# inverse_sparkles               16
# masking_random_color          206
# masking_vline_random_color    206
# perlin_noise                  206
# pinch_and_twirl                16
# pixelate                       16
# plasma_noise                  206
# scatter                        16
# water_drop                     16
# Name: img_id, dtype: int64

# %%
celebahq_fid = FrechetInceptionDistance(reset_real_features=False).to("cuda")

import torch
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from ddpm.datasets.celebahq import CelebAHQ
from torchvision import transforms
t =  transforms.Compose([transforms.ToTensor(), transforms.Resize([256]), transforms.CenterCrop([256, 256])])

class ADataset(Dataset):
    def __init__(self, ds):
        self.ds = ds
        
    def __len__(self):
        return len(self.ds)
    
    def __getitem__(self, idx):
        return self.ds[idx][0]

celeba_dataset = CelebAHQ(root="/mnt/scitas/bastien/CelebAMask-HQ/CelebA-HQ-img/", transform=t)
loader = DataLoader(ADataset(celeba_dataset), batch_size=16, num_workers=4, pin_memory=True)

for batch in tqdm(loader):
    celebahq_fid.update((batch * 255).to(torch.uint8).to("cuda"), real=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 469/469 [11:24<00:00,  1.46s/it]

# %%
from tqdm import tqdm
import torch
from torchmetrics.image import (
    PeakSignalNoiseRatio,
    StructuralSimilarityIndexMeasure,
    LearnedPerceptualImagePatchSimilarity
)

def get_metrics(df, fid_metric):
    metrics = []
    
    for g in tqdm(df.groupby(["corruption"])):
        c = g[0]    
        
        psnr_src_metric = PeakSignalNoiseRatio().to("cuda")
        psnr_tgt_metric = PeakSignalNoiseRatio().to("cuda")
        ssim_src_metric = StructuralSimilarityIndexMeasure(data_range=(0, 1)).to("cuda")
        ssim_tgt_metric = StructuralSimilarityIndexMeasure(data_range=(0, 1)).to("cuda")
        lpips_src_metric = LearnedPerceptualImagePatchSimilarity().to("cuda")
        lpips_tgt_metric = LearnedPerceptualImagePatchSimilarity().to("cuda")
        l2_src_metric = []
        l2_tgt_metric = []
        fid_metric.reset()
        
        list_imgs = list(g[1].iterrows())
        for i, img in list_imgs:
            src = t(Image.open(img["path"].parents[0 if img["algo"] == "none" else 2] / "corrupted.png")).to("cuda")
            tgt = t(Image.open(img["path"].parents[0 if img["algo"] == "none" else 2] / "original.png")).to("cuda")
            img = t(Image.open(img["path"])).to("cuda")
            
            psnr_src_metric.update(img, src)
            psnr_tgt_metric.update(img, tgt)
            ssim_src_metric.update(img.unsqueeze(0), src.unsqueeze(0))
            ssim_tgt_metric.update(img.unsqueeze(0), tgt.unsqueeze(0))
            lpips_src_metric.update((img * 2 - 1).unsqueeze(0), (src * 2 - 1).unsqueeze(0))
            lpips_tgt_metric.update((img * 2 - 1).unsqueeze(0), (tgt * 2 - 1).unsqueeze(0))
            l2_src_metric.append(torch.linalg.norm((img - src).reshape(-1)))
            l2_tgt_metric.append(torch.linalg.norm((img - tgt).reshape(-1)))
            fid_metric.update((img * 255).to(torch.uint8).unsqueeze(0), real=False)
    
        psnr_to_source = psnr_src_metric.compute()
        psnr_to_target = psnr_tgt_metric.compute()
        ssim_to_source = ssim_src_metric.compute()
        ssim_to_target = ssim_tgt_metric.compute()
        l2_to_source = torch.stack(l2_src_metric).mean()
        l2_to_target = torch.stack(l2_tgt_metric).mean()
        lpips_to_source = lpips_src_metric.compute()
        lpips_to_target = lpips_tgt_metric.compute()
        fid = fid_metric.compute()
        
        metrics.append({
            "corruption": c[0],
            "psnr_to_source": psnr_to_source.item(),
            "psnr_to_target": psnr_to_target.item(),
            "ssim_to_source": ssim_to_source.item(),
            "ssim_to_target": ssim_to_target.item(),
            "l2_to_source": l2_to_source.item(),
            "l2_to_target": l2_to_target.item(),
            "lpips_to_source": lpips_to_source.item(),
            "lpips_to_target": lpips_to_target.item(),
            "fid": fid.item(),
            "num_imgs": len(list(g[1].iterrows()))
        })
        
    return pd.DataFrame(metrics)

# %%
import pandas as pd
info = []
for f in files:
    f_split = str(f).split("/")
    if f.name in ["corrupted.png", "original.png"]:
        info.append({
            "path": f,
            "corruption": f_split[-3],
            "img_id": f_split[-2],
            "filename": f_split[-1],
            "algo": "none",
            "clipping": "none",
            "timestamp": f_split[-4],
        })
    else:
        info.append({
            "path": f,
            "corruption": f_split[-5],
            "img_id": f_split[-4],
            "filename": f_split[-1],
            "algo": f_split[-3],
            "clipping": f_split[-2],
            "timestamp": f_split[-6],
        })

df = pd.DataFrame(info)

# %%
df
# Out:
#                                                     path    corruption img_id  \
# 0      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 1      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 2      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 3      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# 4      /home/tmartorella/imgs_for_metrics/fid/2024-05...      pixelate  25048
# ...                                                  ...           ...    ...
# 14579  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14580  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14581  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14582  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
# 14583  /home/tmartorella/imgs_for_metrics/fid/2024-05...  plasma_noise    913
#
#                       filename            algo     clipping         timestamp
# 0                corrupted.png            none         none  2024-05-22_12-40
# 1                 original.png            none         none  2024-05-22_12-40
# 2                    399_0.png             sde  non_clipped  2024-05-22_12-40
# 3             200_0.0001_0.png             ode      clipped  2024-05-22_12-40
# 4              200_0.002_0.png             ode      clipped  2024-05-22_12-40
# ...                        ...             ...          ...               ...
# 14579         200_0.0002_0.png             ode  non_clipped  2024-05-21_23-02
# 14580          200_0.001_0.png             ode  non_clipped  2024-05-21_23-02
# 14581    200_0.000447214_0.png             ode  non_clipped  2024-05-21_23-02
# 14582  reconstruction_ddim.png  reconstruction      clipped  2024-05-21_23-02
# 14583  reconstruction_ddim.png  reconstruction  non_clipped  2024-05-21_23-02
#
# [14584 rows x 7 columns]

# %%
dfs = {
    "reconstruction_without_clipping": {
        "df": df[(df["algo"] == "reconstruction") & (df["clipping"] == "non_clipped")].copy().drop(columns=["timestamp"]).copy()
    },
    "reconstruction_with_clipping": {
        "df": df[(df["algo"] == "reconstruction") & (df["clipping"] == "clipped")].copy().drop(columns=["timestamp"]).copy()
    },
    "ode_without_clipping": {
        "df": df[(df["algo"] == "ode") & (df["clipping"] == "non_clipped")].copy().drop(columns=["timestamp"]).copy()
    },
    "ode_with_clipping": {
        "df": df[(df["algo"] == "ode") & (df["clipping"] == "clipped")].copy().drop(columns=["timestamp"]).copy()
    },
    "sde_without_clipping": {
        "df": df[(df["algo"] == "sde") & (df["clipping"] == "non_clipped")].copy().drop(columns=["timestamp"]).copy()
    },
    "original": {
        "df": df[(df["algo"] == "none") & (df["filename"] == "original.png")].copy().drop(columns=["timestamp"]).copy()
    },
    "corrupted": {
        "df": df[(df["algo"] == "none") & (df["filename"] == "corrupted.png")].copy().drop(columns=["timestamp"]).copy()
    },
}

# %%
from IPython.display import display, Markdown

for k, v in dfs.items():
    if k not in ["corrupted", "original"]:
        continue
    
    metrics_per_corruption = get_metrics(v["df"].copy(), celebahq_fid)
    display(Markdown(f"## {k}"))
    display(metrics_per_corruption)

    v["metrics_per_corruption"] = metrics_per_corruption

    _fake_df = v["df"].copy()
    _fake_df["corruption"] = "all"

    metrics_aggregated = get_metrics(_fake_df.copy(), celebahq_fid)
    display(Markdown(f"## {k} - aggregated"))
    display(metrics_aggregated)
    
    v["metrics_aggregated"] = metrics_aggregated
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# ## reconstruction_without_clipping
#                     corruption  psnr_to_source  psnr_to_target  \
# 0               brownish_noise       33.225513       16.662786
# 1                caustic_noise       27.140509       17.575453
# 2           caustic_refraction       25.192287       19.399538
# 3          checkerboard_cutout       29.253408       16.562868
# 4         cocentric_sine_waves       21.867680       18.237171
# 5                     fish_eye       27.003433       17.611645
# 6                gaussian_blur       35.286160       21.692070
# 7             inverse_sparkles       23.904257        9.511764
# 8         masking_random_color       39.966961       11.689943
# 9   masking_vline_random_color       38.997715       11.506734
# 10                perlin_noise       21.587833       16.793949
# 11             pinch_and_twirl       32.815002       24.294994
# 12                    pixelate       30.905474       23.759485
# 13                plasma_noise       28.855375       18.652555
# 14                     scatter       34.842262       16.042095
# 15                  water_drop       32.151688       22.621046
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0         0.946103        0.741651      6.936468     64.845680
# 1         0.873486        0.740701     15.553489     58.117165
# 2         0.836159        0.615427     20.963127     46.459045
# 3         0.890337        0.705010     13.594751     64.467697
# 4         0.833034        0.446332     28.404007     50.151634
# 5         0.838150        0.419762     17.235472     57.514568
# 6         0.919496        0.538507      7.363235     36.121010
# 7         0.740600        0.508467     26.953619    145.905685
# 8         0.993666        0.237367      4.285335    113.057686
# 9         0.996968        0.161408      4.682489    117.437515
# 10        0.681783        0.535561     32.637791     62.599724
# 11        0.938871        0.741965      8.289534     26.554922
# 12        0.923160        0.623578      9.683135     27.945438
# 13        0.916127        0.677502     11.234311     50.861774
# 14        0.981602        0.190861      7.028390     69.143082
# 15        0.926829        0.708072      9.294833     31.850683
#
#     lpips_to_source  lpips_to_target         fid  num_imgs
# 0          0.046587         0.326223  196.388412        12
# 1          0.141721         0.208787  176.033417        12
# 2          0.184805         0.341567  206.411652        12
# 3          0.107694         0.355170  242.501373       201
# 4          0.167484         0.463822  356.275970        12
# 5          0.184375         0.467431  357.767365        12
# 6          0.174090         0.507168  186.975159        12
# 7          0.301696         0.434771  274.620697        12
# 8          0.001225         1.074974  233.357834       201
# 9          0.001743         0.870393  354.384613       201
# 10         0.398192         0.449768  161.009995       201
# 11         0.042867         0.102850  147.331314        12
# 12         0.093305         0.403477  207.463455        12
# 13         0.087326         0.324672  138.958099       201
# 14         0.018264         0.951293  516.709961        12
# 15         0.060469         0.138565  153.994659        12
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## reconstruction_without_clipping - aggregated
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       27.162848        14.31604        0.894763        0.475805
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target         fid  \
# 0     13.408826     78.688309         0.120334         0.589465  147.212692
#
#    num_imgs
# 0      1137
#   0%|          | 0/16 [00:00<?, ?it/s]
# ## reconstruction_with_clipping
#                     corruption  psnr_to_source  psnr_to_target  \
# 0               brownish_noise       26.121008       16.665329
# 1                caustic_noise       24.327139       17.971403
# 2           caustic_refraction       23.106516       21.786087
# 3          checkerboard_cutout       22.168167       17.770895
# 4         cocentric_sine_waves       22.303226       24.638702
# 5                     fish_eye       23.165741       19.306591
# 6                gaussian_blur       28.390585       21.145803
# 7             inverse_sparkles       21.539570        9.456810
# 8         masking_random_color       17.793606       14.219425
# 9   masking_vline_random_color       16.406998       15.527749
# 10                perlin_noise       24.962128       19.699339
# 11             pinch_and_twirl       26.150476       23.897123
# 12                    pixelate       26.826538       24.031101
# 13                plasma_noise       24.168919       19.266645
# 14                     scatter       17.372326       18.380035
# 15                  water_drop       25.813967       22.643848
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0         0.838245        0.694333     20.130707     64.842552
# 1         0.784794        0.723403     25.950750     55.543327
# 2         0.720731        0.704153     30.723995     35.611797
# 3         0.742535        0.675802     33.903587     55.517780
# 4         0.592351        0.747690     33.737755     25.377188
# 5         0.738789        0.538276     30.293221     47.491699
# 6         0.922678        0.547009     16.240461     38.496040
# 7         0.619701        0.497884     36.733440    147.687927
# 8         0.806903        0.318623     52.291435     82.995140
# 9         0.734294        0.294387     66.852051     73.170410
# 10        0.804540        0.696162     24.711369     45.447968
# 11        0.803418        0.710530     21.182844     27.766981
# 12        0.828557        0.676054     19.877476     27.506834
# 13        0.799437        0.716327     25.510353     47.960068
# 14        0.337891        0.468810     59.474411     52.766731
# 15        0.790906        0.693317     22.317007     31.986137
#
#     lpips_to_source  lpips_to_target         fid  num_imgs
# 0          0.177310         0.384999  186.885651        12
# 1          0.223206         0.240173  172.621185        12
# 2          0.281053         0.267829  191.160568        12
# 3          0.385263         0.332165  109.424927       201
# 4          0.376157         0.198236  183.257660        12
# 5          0.444426         0.400741  181.379181        12
# 6          0.206648         0.479005  194.682678        12
# 7          0.449115         0.489915  210.760651        12
# 8          0.374036         0.777271  149.777832       201
# 9          0.281918         0.664414  298.121735       201
# 10         0.263903         0.262264   89.001801       201
# 11         0.206322         0.245638  172.694275        12
# 12         0.445016         0.311268  176.990387        12
# 13         0.240257         0.286732   85.445465       201
# 14         0.922430         0.507865  229.002701        12
# 15         0.209608         0.261046  192.451736        12
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## reconstruction_with_clipping - aggregated
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       20.053694       16.823309        0.771474        0.551432
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0     39.276142      59.79269          0.31479         0.450601  84.666672
#
#    num_imgs
# 0      1137
#   0%|          | 0/16 [00:00<?, ?it/s]
# ## ode_without_clipping
#                     corruption  psnr_to_source  psnr_to_target  \
# 0               brownish_noise       19.256689       16.323790
# 1                caustic_noise       20.435217       17.078411
# 2           caustic_refraction       20.055094       20.439356
# 3          checkerboard_cutout       19.384977       15.998348
# 4         cocentric_sine_waves       19.683847       21.575821
# 5                     fish_eye       20.825779       18.482861
# 6                gaussian_blur       24.254257       20.281818
# 7             inverse_sparkles       20.598839        9.507915
# 8         masking_random_color       13.520676       14.728349
# 9   masking_vline_random_color       12.519159       15.807421
# 10                perlin_noise       22.553141       17.602627
# 11             pinch_and_twirl       21.955988       21.565779
# 12                    pixelate       22.745974       21.650078
# 13                plasma_noise       20.068745       18.431944
# 14                     scatter       17.310068       19.130720
# 15                  water_drop       21.557196       21.040110
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0         0.512312        0.507242     46.204094     67.459557
# 1         0.561114        0.540488     40.873226     61.852879
# 2         0.513504        0.557496     42.882660     41.577591
# 3         0.530180        0.495348     46.576077     69.121674
# 4         0.360887        0.576972     45.320652     36.141460
# 5         0.563595        0.478409     38.942005     52.248920
# 6         0.726637        0.521745     25.678545     42.293194
# 7         0.507744        0.390023     40.114197    146.104446
# 8         0.147915        0.479740     91.878456     80.002449
# 9         0.107939        0.426255    104.659729     71.154999
# 10        0.621528        0.538386     32.292416     57.745918
# 11        0.610888        0.586139     34.189381     36.203625
# 12        0.635888        0.581370     31.087833     35.541313
# 13        0.502649        0.563991     43.055729     52.676182
# 14        0.233840        0.471560     59.605110     48.342712
# 15        0.600075        0.580213     35.781651     38.506325
#
#     lpips_to_source  lpips_to_target         fid  num_imgs
# 0          0.302242         0.378966  132.249634        36
# 1          0.231120         0.241409  126.193100        36
# 2          0.267652         0.227296  138.559952        36
# 3          0.422252         0.340637   43.878151       794
# 4          0.407709         0.200878  130.784668        36
# 5          0.426021         0.294639  128.090317        36
# 6          0.524971         0.267856  125.149765        36
# 7          0.408331         0.487912  165.143204        36
# 8          1.037450         0.443043   42.969093       794
# 9          0.800120         0.406525   68.092079       794
# 10         0.241085         0.249181   36.582005       794
# 11         0.180037         0.184592  128.433945        36
# 12         0.446880         0.191307  126.456604        36
# 13         0.338886         0.282837   39.591518       794
# 14         0.944616         0.318238  129.544891        36
# 15         0.196579         0.195151  128.206894        36
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## ode_without_clipping - aggregated
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       16.203596       16.360512        0.395433        0.503081
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0      61.54916     65.140305         0.552198         0.337842  23.434536
#
#    num_imgs
# 0      4366
#   0%|          | 0/16 [00:00<?, ?it/s]
# ## ode_with_clipping
#                     corruption  psnr_to_source  psnr_to_target  \
# 0               brownish_noise       18.847744       16.289310
# 1                caustic_noise       19.622019       16.919168
# 2           caustic_refraction       19.303566       20.117157
# 3          checkerboard_cutout       18.483440       16.758698
# 4         cocentric_sine_waves       19.207561       21.152426
# 5                     fish_eye       19.856300       18.608702
# 6                gaussian_blur       23.287668       19.752218
# 7             inverse_sparkles       19.299818        9.330025
# 8         masking_random_color       12.755767       16.376781
# 9   masking_vline_random_color       12.177476       17.486828
# 10                perlin_noise       21.237850       18.075428
# 11             pinch_and_twirl       21.192791       21.018021
# 12                    pixelate       22.195547       21.102036
# 13                plasma_noise       19.236048       18.153652
# 14                     scatter       16.369427       18.530073
# 15                  water_drop       20.893341       20.564684
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0         0.508399        0.508693     48.950623     67.614166
# 1         0.542042        0.540579     45.402393     62.591099
# 2         0.495420        0.560948     47.297813     42.994968
# 3         0.518448        0.515241     52.113293     63.029068
# 4         0.339193        0.587879     48.044144     37.888996
# 5         0.551200        0.493996     44.294979     51.493809
# 6         0.712878        0.497371     29.404999     45.098518
# 7         0.475586        0.389907     47.576233    149.977783
# 8         0.148555        0.506442    100.459541     65.604744
# 9         0.119090        0.476750    108.931442     58.136829
# 10        0.610300        0.544957     37.914413     54.805878
# 11        0.593447        0.574932     37.626690     38.530701
# 12        0.631373        0.568317     33.621254     38.260063
# 13        0.494657        0.556563     47.540436     54.370411
# 14        0.213844        0.469575     66.789856     52.130070
# 15        0.579775        0.565706     39.052444     40.700855
#
#     lpips_to_source  lpips_to_target         fid  num_imgs
# 0          0.322136         0.374244  130.405304        36
# 1          0.256363         0.247011  123.796585        36
# 2          0.311166         0.235693  134.792618        36
# 3          0.445382         0.308977   38.901421       790
# 4          0.431545         0.197457  125.790138        36
# 5          0.457936         0.284566  123.988266        36
# 6          0.528375         0.286950  121.960548        36
# 7          0.474140         0.496193  149.280975        36
# 8          1.072847         0.367330   38.398689       790
# 9          0.800525         0.330255   60.602184       790
# 10         0.258020         0.251161   38.406837       790
# 11         0.207955         0.210299  121.248230        36
# 12         0.454843         0.215549  124.933479        36
# 13         0.355399         0.273367   38.701908       790
# 14         0.996638         0.341940  125.827911        36
# 15         0.220856         0.217688  129.085754        36
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## ode_with_clipping - aggregated
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       15.570461       17.242403        0.390493        0.520305
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target       fid  \
# 0     67.111809     58.992222         0.571618         0.304058  21.87541
#
#    num_imgs
# 0      4346
#   0%|          | 0/16 [00:00<?, ?it/s]
# ## sde_without_clipping
#                     corruption  psnr_to_source  psnr_to_target  \
# 0               brownish_noise       20.146896       16.538826
# 1                caustic_noise       21.031092       17.369131
# 2           caustic_refraction       20.477188       21.083298
# 3          checkerboard_cutout       20.394911       16.165697
# 4         cocentric_sine_waves       20.080894       22.496641
# 5                     fish_eye       21.447824       18.742651
# 6                gaussian_blur       25.263248       20.754078
# 7             inverse_sparkles       21.012999        9.817159
# 8         masking_random_color       13.669659       14.979639
# 9   masking_vline_random_color       12.608151       16.284155
# 10                perlin_noise       23.597616       17.899603
# 11             pinch_and_twirl       22.509146       22.091995
# 12                    pixelate       23.577206       22.418768
# 13                plasma_noise       21.091536       18.718658
# 14                     scatter       17.572653       19.761175
# 15                  water_drop       22.102276       21.401022
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0         0.506674        0.513831     43.489246     65.736908
# 1         0.552113        0.537869     39.277027     59.904411
# 2         0.512651        0.579308     41.813652     38.916134
# 3         0.550498        0.507901     42.093140     67.769615
# 4         0.348283        0.607563     43.814995     33.007401
# 5         0.567261        0.496325     37.369629     50.877831
# 6         0.728531        0.537031     24.017870     40.370026
# 7         0.493476        0.407607     39.263115    141.135406
# 8         0.149588        0.510177     90.263557     77.853256
# 9         0.104408        0.454759    103.668686     67.361450
# 10        0.640648        0.554209     29.046642     55.847626
# 11        0.618222        0.601119     33.004524     34.638500
# 12        0.641989        0.601866     29.230566     33.311096
# 13        0.517697        0.574850     38.741787     51.042595
# 14        0.216254        0.495249     58.075760     45.264210
# 15        0.604463        0.592366     34.646233     37.337151
#
#     lpips_to_source  lpips_to_target         fid  num_imgs
# 0          0.298748         0.377522  168.984985        16
# 1          0.222925         0.229087  144.125748        16
# 2          0.261094         0.199185  140.547226        16
# 3          0.399148         0.327353   80.512245       202
# 4          0.403271         0.165341  147.689880        16
# 5          0.423532         0.280955  151.167526        16
# 6          0.538773         0.245560  154.540680        16
# 7          0.414608         0.460137  205.214508        16
# 8          1.051342         0.417342   73.719513       202
# 9          0.816210         0.368527   96.242264       202
# 10         0.214527         0.227425   67.002533       202
# 11         0.162666         0.162451  140.073975        16
# 12         0.432039         0.167465  141.518784        16
# 13         0.310618         0.279033   74.546944       202
# 14         0.970998         0.285169  157.624191        16
# 15         0.186575         0.178269  138.924286        16
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## sde_without_clipping - aggregated
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       16.683807       16.692589        0.412422        0.523698
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0     57.465794     62.312519         0.533724         0.312979  38.042252
#
#    num_imgs
# 0      1186
# 0it [00:00, ?it/s]
# ## original
# Empty DataFrame
# Columns: []
# Index: []
# 0it [00:00, ?it/s]
# ## original - aggregated
# Empty DataFrame
# Columns: []
# Index: []
# 0it [00:00, ?it/s]
# ## corrupted
# Empty DataFrame
# Columns: []
# Index: []
# 0it [00:00, ?it/s]
# ## corrupted - aggregated
# Empty DataFrame
# Columns: []
# Index: []

# %%
from IPython.display import display, Markdown

for k, v in dfs.items():
    if k not in ["corrupted", "original"]:
        continue
    
    metrics_per_corruption = get_metrics(v["df"].copy(), celebahq_fid)
    display(Markdown(f"## {k}"))
    display(metrics_per_corruption)

    v["metrics_per_corruption"] = metrics_per_corruption

    _fake_df = v["df"].copy()
    _fake_df["corruption"] = "all"

    metrics_aggregated = get_metrics(_fake_df.copy(), celebahq_fid)
    display(Markdown(f"## {k} - aggregated"))
    display(metrics_aggregated)
    
    v["metrics_aggregated"] = metrics_aggregated
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# ## original
#                     corruption  psnr_to_source  psnr_to_target  \
# 0               brownish_noise       16.859682             inf
# 1                caustic_noise       18.234344             inf
# 2           caustic_refraction       21.453802             inf
# 3          checkerboard_cutout       16.495350             inf
# 4         cocentric_sine_waves       23.022499             inf
# 5                     fish_eye       18.183718             inf
# 6                gaussian_blur       22.162159             inf
# 7             inverse_sparkles        9.964433             inf
# 8         masking_random_color       11.802941             inf
# 9   masking_vline_random_color       11.639180             inf
# 10                perlin_noise       19.249104             inf
# 11             pinch_and_twirl       25.091566             inf
# 12                    pixelate       25.230808             inf
# 13                plasma_noise       19.365181             inf
# 14                     scatter       16.370817             inf
# 15                  water_drop       22.648865             inf
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0         0.795461        1.000000     63.374878           0.0
# 1         0.849742        1.000000     54.236118           0.0
# 2         0.757663        1.000000     37.165993           0.0
# 3         0.780126        0.999997     64.899422           0.0
# 4         0.578347        1.000000     31.305069           0.0
# 5         0.470227        1.000000     54.175911           0.0
# 6         0.587452        1.000000     34.142033           0.0
# 7         0.578729        1.000000    138.519394           0.0
# 8         0.243072        0.999997    111.564552           0.0
# 9         0.165897        0.999997    115.654999           0.0
# 10        0.805236        0.999997     47.387321           0.0
# 11        0.793460        1.000000     24.444040           0.0
# 12        0.686368        1.000000     24.017954           0.0
# 13        0.758396        0.999997     47.273239           0.0
# 14        0.207424        1.000000     66.655075           0.0
# 15        0.755271        1.000000     31.708775           0.0
#
#     lpips_to_source  lpips_to_target         fid  num_imgs
# 0          0.283796              0.0  136.829468        16
# 1          0.099865              0.0  136.829468        16
# 2          0.192048              0.0  136.829468        16
# 3          0.341479              0.0   50.443966       206
# 4          0.349037              0.0  136.829468        16
# 5          0.464492              0.0  136.829468        16
# 6          0.630953              0.0  136.829468        16
# 7          0.433153              0.0  136.829468        16
# 8          1.071532              0.0   50.443966       206
# 9          0.870197              0.0   50.443966       206
# 10         0.094827              0.0   50.443966       206
# 11         0.066273              0.0  136.829468        16
# 12         0.423658              0.0  136.829468        16
# 13         0.254936              0.0   50.443966       206
# 14         0.950827              0.0  136.829468        16
# 15         0.101546              0.0  136.829468        16
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## original - aggregated
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       14.746831             inf        0.563867        0.999998
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0      73.49295           0.0         0.502755              0.0  48.817364
#
#    num_imgs
# 0      1206
#   0%|          | 0/16 [00:00<?, ?it/s]
# ## corrupted
#                     corruption  psnr_to_source  psnr_to_target  \
# 0               brownish_noise             inf       16.859682
# 1                caustic_noise             inf       18.234344
# 2           caustic_refraction             inf       21.453802
# 3          checkerboard_cutout             inf       16.495350
# 4         cocentric_sine_waves             inf       23.022499
# 5                     fish_eye             inf       18.183718
# 6                gaussian_blur             inf       22.196289
# 7             inverse_sparkles             inf        9.964433
# 8         masking_random_color             inf       11.802941
# 9   masking_vline_random_color             inf       11.639180
# 10                perlin_noise             inf       19.249104
# 11             pinch_and_twirl             inf       25.091566
# 12                    pixelate             inf       25.230808
# 13                plasma_noise             inf       19.399311
# 14                     scatter             inf       16.370817
# 15                  water_drop             inf       22.648865
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0         1.000000        0.795461           0.0     63.374878
# 1         1.000000        0.849742           0.0     54.236118
# 2         1.000000        0.757663           0.0     37.165993
# 3         0.999998        0.780126           0.0     64.899422
# 4         1.000000        0.578347           0.0     31.305069
# 5         0.999992        0.470227           0.0     54.175911
# 6         0.999995        0.587452           0.0     34.142033
# 7         0.999999        0.578729           0.0    138.519394
# 8         1.000000        0.243072           0.0    111.564552
# 9         1.000000        0.165897           0.0    115.654999
# 10        1.000000        0.805236           0.0     47.387321
# 11        1.000000        0.793460           0.0     24.444040
# 12        0.999999        0.686368           0.0     24.017954
# 13        1.000000        0.758396           0.0     47.273239
# 14        1.000000        0.207424           0.0     66.655075
# 15        1.000000        0.755271           0.0     31.708775
#
#     lpips_to_source  lpips_to_target         fid  num_imgs
# 0               0.0         0.283796  169.313644        16
# 1               0.0         0.099865  154.926849        16
# 2               0.0         0.192048  167.762604        16
# 3               0.0         0.341479  270.342499       206
# 4               0.0         0.349037  337.507294        16
# 5               0.0         0.464492  408.461365        16
# 6               0.0         0.630953  231.149490        16
# 7               0.0         0.433153  303.855286        16
# 8               0.0         1.071532  230.866531       206
# 9               0.0         0.870197  355.248138       206
# 10              0.0         0.094827   74.485847       206
# 11              0.0         0.066273  142.174881        16
# 12              0.0         0.423658  199.345596        16
# 13              0.0         0.254936  113.048218       206
# 14              0.0         0.950827  511.104584        16
# 15              0.0         0.101546  152.617981        16
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## corrupted - aggregated
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all             inf       14.746831             1.0        0.563867
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target         fid  \
# 0           0.0      73.49295              0.0         0.502755  127.835823
#
#    num_imgs
# 0      1206

# %%
from IPython.display import display, Markdown

for k, v in dfs.items():
    # if k not in ["corrupted", "original"]:
    #     continue
    
    # metrics_per_corruption = get_metrics(v["df"].copy(), celebahq_fid)
    # display(Markdown(f"## {k}"))
    # display(metrics_per_corruption)

    # v["metrics_per_corruption"] = metrics_per_corruption

    _fake_df = v["df"].copy()
    _fake_df[_fake_df["corruption"].isin(["checkerboard_cutout", "perlin_noise", "masking_random_color", "masking_vline_random_color", "plasma_noise"])] 
    _fake_df["corruption"] = "all"

    metrics_aggregated = get_metrics(_fake_df.copy(), celebahq_fid)
    display(Markdown(f"## {k} - aggregated (only ablation)"))
    display(metrics_aggregated)
    
    v["metrics_aggregated"] = metrics_aggregated
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## reconstruction_without_clipping - aggregated (only ablation)
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       27.162848        14.31604        0.894763        0.475805
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target         fid  \
# 0     13.408826     78.688309         0.120334         0.589465  147.212692
#
#    num_imgs
# 0      1137
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## reconstruction_with_clipping - aggregated (only ablation)
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       20.053694       16.823309        0.771474        0.551432
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0     39.276142      59.79269          0.31479         0.450601  84.666672
#
#    num_imgs
# 0      1137
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## ode_without_clipping - aggregated (only ablation)
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       16.203596       16.360512        0.395433        0.503081
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0      61.54916     65.140305         0.552198         0.337842  23.434536
#
#    num_imgs
# 0      4366
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## ode_with_clipping - aggregated (only ablation)
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       15.570461       17.242403        0.390493        0.520305
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target       fid  \
# 0     67.111809     58.992222         0.571618         0.304058  21.87541
#
#    num_imgs
# 0      4346
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## sde_without_clipping - aggregated (only ablation)
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       16.683807       16.692589        0.412422        0.523698
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0     57.465794     62.312519         0.533724         0.312979  38.042252
#
#    num_imgs
# 0      1186
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## original - aggregated (only ablation)
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       14.746831             inf        0.563867        0.999998
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid  \
# 0      73.49295           0.0         0.502755              0.0  48.817364
#
#    num_imgs
# 0      1206
#   0%|          | 0/1 [00:00<?, ?it/s]
# ## corrupted - aggregated (only ablation)
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all             inf       14.746831             1.0        0.563867
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target         fid  \
# 0           0.0      73.49295              0.0         0.502755  127.835823
#
#    num_imgs
# 0      1206

# %%
import pickle
with open("/home/tmartorella/imgs_for_metrics/metrics_new.pkl", "wb") as metrics_file:
    pickle.dump(dfs, metrics_file)

# %%
ode = df[(df["algo"] == "ode") & (df["corruption"].isin(["contrast", "fog"]))].drop(columns=["timestamp"])
ode_results_per_corruption = get_metrics(ode, celebahq_fid)
ode_results_per_corruption
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 2/2 [01:06<00:00, 33.48s/it]
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0   contrast       19.456379       14.005204        0.704571        0.466285
# 1        fog       18.370485       12.637938        0.599688        0.423423
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid
# 0     37.227726     86.310837         0.566833         0.413938  51.584625
# 1     49.261127    101.670357         0.444414         0.434942  50.019432

# %%
sde = df[(df["algo"] == "sde") & (df["corruption"].isin(["contrast", "fog"]))].drop(columns=["timestamp"])
sde_results_per_corruption = get_metrics(sde, celebahq_fid)
sde_results_per_corruption
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:44<00:00, 22.06s/it]
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0   contrast       31.507917       12.398882        0.825937        0.352600
# 1        fog       26.394199       11.563744        0.707346        0.363064
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target         fid
# 0      9.956234    104.480896         0.535663         0.814965  330.311615
# 1     20.327606    115.654778         0.416586         0.654471  196.135605

# %%
# ode = df[(df["algo"] == "ode") & (df["corruption"] == "fog")].drop(columns=["timestamp"])
ode_all = df[(df["algo"] == "ode")].copy()
ode_all["corruption"] = "all"
ode_results_all = get_metrics(ode_all, celebahq_fid)
ode_results_all
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 1/1 [04:12<00:00, 252.90s/it]
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all         15.8325       14.758712        0.531907         0.51153
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid
# 0     55.553547     69.620918         0.544291         0.349669  27.974178

# %%
sde_all = df[(df["algo"] == "sde")].copy()
sde_all["corruption"] = "all"
sde_results_all = get_metrics(sde_all, celebahq_fid)
sde_results_all
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 1/1 [05:42<00:00, 342.72s/it]
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all       16.148903       14.417244        0.490403        0.517865
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target        fid
# 0     53.025021     72.267281          0.62709         0.368789  59.296925

# %%
# ode = df[(df["algo"] == "ode") & (df["corruption"] == "fog")].drop(columns=["timestamp"])
corrupted_all = df[(df["algo"] == "none") & (df["filename"] == "corrupted.png")].copy()
# corrupted_all["corruption"] = "all"
corrupted_results_all = get_metrics(corrupted_all, celebahq_fid)
corrupted_results_all
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 1/1 [01:01<00:00, 61.27s/it]
#   corruption  psnr_to_source  psnr_to_target  ssim_to_source  ssim_to_target  \
# 0        all             inf       12.579247             1.0        0.428789
#
#    l2_to_source  l2_to_target  lpips_to_source  lpips_to_target         fid
# 0           0.0     94.061813              0.0         0.683682  113.806267

# %%
# ode = df[(df["algo"] == "ode") & (df["corruption"] == "fog")].drop(columns=["timestamp"])
corrupted_all = df[(df["algo"] == "none") & (df["filename"] == "corrupted.png")].copy()
# corrupted_all["corruption"] = "all"
corrupted_results_all = get_metrics(corrupted_all, celebahq_fid)
corrupted_results_all
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████| 17/17 [01:41<00:00,  5.94s/it]
#                     corruption  psnr_to_source  psnr_to_target  \
# 0                   brightness             inf        9.852933
# 1                     contrast             inf       12.546547
# 2            elastic_transform             inf       19.798203
# 3                          fog             inf       11.679802
# 4                        frost             inf        9.333415
# 5                gaussian_blur             inf       22.107393
# 6               gaussian_noise             inf       10.650517
# 7                   glass_blur             inf       22.184576
# 8                impulse_noise             inf       10.400298
# 9             jpeg_compression             inf       25.767984
# 10        masking_random_color             inf       11.755529
# 11  masking_vline_random_color             inf       11.681780
# 12                    pixelate             inf       25.376385
# 13                    saturate             inf       10.736112
# 14                  shot_noise             inf       10.496242
# 15                     spatter             inf       16.500881
# 16               speckle_noise             inf       12.505755
#
#     ssim_to_source  ssim_to_target  l2_to_source  l2_to_target  \
# 0              1.0        0.618916           0.0    140.778976
# 1              1.0        0.436881           0.0    102.690407
# 2              1.0        0.566378           0.0     44.225132
# 3              1.0        0.524399           0.0    114.024574
# 4              1.0        0.436469           0.0    145.133148
# 5              1.0        0.618729           0.0     34.124580
# 6              1.0        0.058202           0.0    130.082214
# 7              1.0        0.622470           0.0     33.846889
# 8              1.0        0.068457           0.0    133.768524
# 9              1.0        0.709763           0.0     22.577734
# 10             1.0        0.248499           0.0    111.912430
# 11             1.0        0.170484           0.0    114.956444
# 12             1.0        0.719315           0.0     22.987164
# 13             1.0        0.532065           0.0    124.458130
# 14             1.0        0.090028           0.0    131.597168
# 15             1.0        0.585926           0.0     63.964310
# 16             1.0        0.227650           0.0    103.302666
#
#     lpips_to_source  lpips_to_target         fid
# 0               0.0         0.257829   98.784233
# 1               0.0         0.747116  112.282906
# 2               0.0         0.254095  218.191284
# 3               0.0         0.444118  183.971191
# 4               0.0         0.561487  220.817673
# 5               0.0         0.609321  159.776321
# 6               0.0         1.331478  321.960663
# 7               0.0         0.461552  225.536407
# 8               0.0         1.335539  288.324066
# 9               0.0         0.310088  125.927399
# 10              0.0         1.070919  282.167297
# 11              0.0         0.868246  380.767273
# 12              0.0         0.431489  221.968491
# 13              0.0         0.355578  175.891937
# 14              0.0         1.252841  296.435699
# 15              0.0         0.494955  264.877777
# 16              0.0         1.020999  233.461456

# %%
ode_results_per_corruption.to_csv("/home/martorel/dev/unsupervised_image_editing/ode_results_per_corruption_top_16_all.csv")
sde_results_per_corruption.to_csv("/home/martorel/dev/unsupervised_image_editing/sde_results_per_corruption_top_16_all.csv")
ode_results_all.to_csv("/home/martorel/dev/unsupervised_image_editing/ode_results_all_top_16_all.csv")
sde_results_all.to_csv("/home/martorel/dev/unsupervised_image_editing/sde_results_all_top_16_all.csv")
